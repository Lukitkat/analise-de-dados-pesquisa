# %%
import pandas as pd
import numpy as np
import re
import unicodedata

# %% [markdown]
# # 1. **Leitura dos dados**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Lukitkat/analise-de-dados-pesquisa/refs/heads/main/Forms%20_ORIGINAL_%20(respostas).csv')

# %% [markdown]
# # 2. **Dicionario de dados e limpeza**

# %%
df = df.drop(columns=df.columns[:2])
df = df.drop(df.columns[-1], axis=1)

# %%
mapeamentos = {
    "Qual a sua idade?": {
        "18 a 25": 1, "25 a 30": 2, "30 a 40": 3, "40 ou mais": 4
    },
    "Como você se identifica?": {
        "Branco(a)": 1, "Preto(a)": 2, "Pardo(a)": 3, "Amarelo(a)": 4
    },
    "Qual o seu nível de escolaridade?": {
        "Fundamental incompleto": 1, "Fundamental completo": 2, "Médio incompleto": 3,
        "Médio completo": 4, "Médio cursando": 5, "Superior incompleto": 6,
        "Superior completo": 7, "Superior cursando": 8, "Pós graduação": 9
    },
    "Há quanto tempo você trabalha em shopping?": {
        "Menos de 1 ano": 1, "1 a 2 anos": 2, "3 a 5 anos": 3, "5 a 10 anos": 4,
        "10 a 15 anos": 5, "15 anos ou mais": 6
    },
    "Em qual área você trabalha?": {
        "Comércio": 1, "Segurança": 2, "Serviços gerais": 3, "Alimentação": 4, "Administrativo": 5
    },
    "Quantas horas por semana você trabalha no total?": {
        "20 a 25 horas semanais": 1, "25 a 30 horas semanais": 2, "30 a 35 horas semanais": 3,
        "35 a 40 horas semanais": 4, "40 a 44 horas semanais": 5, "44 horas ou mais": 6
    },
    "Você tem outro trabalho?": {
        "Sim": 1, "Não": 2
    },
    "Você possui dependentes financeiros? ": {
        "Sim": 1, "Não": 2
    },
    "Sua residência é:": {
        "Alugada": 1, "Própria": 2
    },
    "Qual a distância de sua residência ao seu lugar de trabalho?": {
        "0 a 5 km": 1, "5 a 10 km": 2, "10 a 15 km": 3, "15 a 20 km": 4, "20 km ou mais": 5,
        "Indígena": 6
    },
    "Qual é a sua identidade de gênero?": {
        "Homem cis": 1, "Homem trans": 2, "Mulher cis": 3, "Mulher trans": 4,
        "Não binário": 5, "Prefiro não responder": 6
    },
    "Qual é a sua sexualidade?": {
        "Heterossexual": 1, "Homossexual": 2, "Bissexual": 3,
        "Panssexual": 4, "Assexual": 5, "Prefiro não responder": 6
    }
}

for coluna, dicionario in mapeamentos.items():

  if coluna in df.columns:

    df[coluna] = df[coluna].map(dicionario)

# %%
df.describe()
# Out:
#        Qual a sua idade?  Como você se identifica?  \
# count         106.000000                106.000000
# mean            2.103774                  2.358491
# std             1.022874                  0.896434
# min             1.000000                  1.000000
# 25%             1.000000                  1.000000
# 50%             2.000000                  3.000000
# 75%             3.000000                  3.000000
# max             4.000000                  4.000000
#
#        Qual é a sua identidade de gênero?  Qual é a sua sexualidade?  \
# count                          105.000000                 106.000000
# mean                             2.580952                   1.547170
# std                              1.044960                   0.986886
# min                              1.000000                   1.000000
# 25%                              2.000000                   1.000000
# 50%                              3.000000                   1.000000
# 75%                              3.000000                   2.000000
# max                              6.000000                   6.000000
#
#        Qual o seu nível de escolaridade?  \
# count                         103.000000
# mean                            5.592233
# std                             1.901686
# min                             1.000000
# 25%                             4.000000
# 50%                             6.000000
# 75%                             8.000000
# max                             8.000000
#
#        Há quanto tempo você trabalha em shopping?  \
# count                                  106.000000
# mean                                     2.858491
# std                                      1.681488
# min                                      1.000000
# 25%                                      1.000000
# 50%                                      3.000000
# 75%                                      4.000000
# max                                      6.000000
#
#        Em qual área você trabalha?  \
# count                   106.000000
# mean                      1.424528
# std                       1.068583
# min                       1.000000
# 25%                       1.000000
# 50%                       1.000000
# 75%                       1.000000
# max                       5.000000
#
#        Quantas horas por semana você trabalha no total?  \
# count                                        106.000000
# mean                                           4.981132
# std                                            1.479904
# min                                            1.000000
# 25%                                            5.000000
# 50%                                            5.000000
# 75%                                            6.000000
# max                                            6.000000
#
#        Você tem outro trabalho?  Você possui dependentes financeiros?   \
# count                106.000000                             106.000000
# mean                   1.915094                               1.518868
# std                    0.280065                               0.502017
# min                    1.000000                               1.000000
# 25%                    2.000000                               1.000000
# 50%                    2.000000                               2.000000
# 75%                    2.000000                               2.000000
# max                    2.000000                               2.000000
#
#        Sua residência é:  \
# count         106.000000
# mean            1.490566
# std             0.502286
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             2.000000
# max             2.000000
#
#        Qual a distância de sua residência ao seu lugar de trabalho?
# count                                         106.000000
# mean                                            3.028302
# std                                             1.396987
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000

# %%
def extrair_numero(texto):

  if isinstance(texto, str):

    match = re.search(r"\((\d+)\)", texto)
    return int(match.group(1)) if match else texto

  return texto

df = df.applymap(extrair_numero)
# Out:
# <ipython-input-462-ac0e0b8bdaf3>:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(extrair_numero)

# %%
df.isnull().sum()
# Out:
# Qual a sua idade?                                                                                                                                0
# Como você se identifica?                                                                                                                         0
# Qual é a sua identidade de gênero?                                                                                                               1
# Qual é a sua sexualidade?                                                                                                                        0
# Qual o seu nível de escolaridade?                                                                                                                3
# Há quanto tempo você trabalha em shopping?                                                                                                       0
# Em qual área você trabalha?                                                                                                                      0
# Quantas horas por semana você trabalha no total?                                                                                                 0
# Você tem outro trabalho?                                                                                                                         0
# Você possui dependentes financeiros?                                                                                                             0
# Sua residência é:                                                                                                                                0
# Qual a distância de sua residência ao seu lugar de trabalho?                                                                                     0
# 1.1) Em termos gerais, a minha atividade profissional provoca-me…                                                                                0
# 2.1) A falta de possibilidades de desenvolvimento e promoção na carreira                                                                         2
# 2.2) Atitudes negativas relativamente ao nosso trabalho por parte das pessoas a quem presto os meus serviços (ex: clientes, cidadãos, etc.)      0
# 2.3) Falta de tempo para manter uma boa relação com as pessoas mais próximas (ex: cônjuge, filhos, amigos, etc.)                                 0
# 2.4) Conflitos e problemas com colegas de trabalho                                                                                               2
# 2.5) Trabalhar muitas horas seguidas                                                                                                             0
# 2.6) Viver com os recursos financeiros/salário de que disponho                                                                                   0
# 2.7) Falta de condições de trabalho                                                                                                              1
# 2.8) Incompreensão face ao nosso trabalho por parte das pessoas a quem presto os meus serviços (ex: clientes, cidadãos, etc.)                    0
# 2.9) Falta de materiais e equipamentos para realizar o meu trabalho                                                                              1
# 2.10) O excesso de trabalho e/ou tarefas de caráter burocrático                                                                                  0
# 2.11) Ter de realizar muitas horas seguidas de trabalho                                                                                          0
# 2.12) Conflitos e problemas com superiores hierárquicos                                                                                          1
# 2.13) Cumprir com aquilo que é esperado pelas pessoas a quem presto os meus serviços (ex: clientes, cidadãos, etc.)                              1
# 2.14) Falta de tempo para dar apoio e conviver com a minha família/amigos                                                                        1
# 2.15) Falta de perspectivas de progressão na carreira                                                                                            1
# 2.16) A sobrecarga ou excesso de trabalho                                                                                                        1
# 2.17) Os conflitos interpessoais com outros colegas de trabalho                                                                                  1
# 2.18) Falta de meios e condições de trabalho                                                                                                     2
# 2.19) Salário inadequado/insuficiente                                                                                                            2
# 2.20) A falta de apoio e ajuda por parte dos meus superiores                                                                                     1
# 2.21) Nível de exigência das pessoas a quem presto os meus serviços (ex: clientes, cidadãos, etc.)                                               1
# 2.22) Comportamentos incorretos e/ou inadequados de colegas de trabalho                                                                          2
# 2.23) Falta de tempo para estar com a família/amigos                                                                                             0
# 2.24) O favoritismo e/ou discriminação “encobertos” no meu local de trabalho por parte dos meus superiores                                       0
# Com que frequência você consegue passar tempo de qualidade com familiares e amigos?                                                              0
# Com que frequência você tem acesso a atividades de lazer, como leitura, assistir filmes ou ir à praia?                                           0
# Com que frequência você consegue praticar exercícios físicos?                                                                                    0
# Com que frequência você consegue ir ao médico para check-ups ou cuidar da sua saúde?                                                             0
# Com que frequência você consegue dedicar tempo aos estudos?                                                                                      0
# Com que frequência você consegue realizar as atividades domésticas necessárias?                                                                  0
# Com que frequência você consegue descansar o suficiente no seu cotidiano?                                                                        0
# dtype: int64

# %%
def limpar_nome_coluna(nome):

  # Remover acentos
  nome = unicodedata.normalize('NFKD', nome).encode('ASCII', 'ignore').decode('utf-8')

  # Substituir caracteres não alfanuméricos por "_"
  nome = re.sub(r'[^a-zA-Z0-9]+', '_', nome)

  # Remover underscores duplicados ou no início/fim
  nome = re.sub(r'_+', '_', nome).strip('_')

  # Limitar a 64 caracteres e deixar tudo em minúsculo
  return nome[:64].lower()

df.columns = [limpar_nome_coluna(col) for col in df.columns]

# %%
df_final = df.dropna()

# %%
df_final.to_csv('dicionario.csv', index=False)

# %% [markdown]
# # 3. **Análise descritiva dos dados**

# %%
df_final.describe()
# Out:
#        qual_a_sua_idade  como_voce_se_identifica  \
# count         95.000000                95.000000
# mean           2.073684                 2.368421
# std            0.991905                 0.899795
# min            1.000000                 1.000000
# 25%            1.000000                 1.000000
# 50%            2.000000                 3.000000
# 75%            3.000000                 3.000000
# max            4.000000                 4.000000
#
#        qual_e_a_sua_identidade_de_genero  qual_e_a_sua_sexualidade  \
# count                          95.000000                 95.000000
# mean                            2.578947                  1.568421
# std                             1.067697                  0.996298
# min                             1.000000                  1.000000
# 25%                             1.500000                  1.000000
# 50%                             3.000000                  1.000000
# 75%                             3.000000                  2.000000
# max                             6.000000                  6.000000
#
#        qual_o_seu_nivel_de_escolaridade  \
# count                         95.000000
# mean                           5.557895
# std                            1.900256
# min                            1.000000
# 25%                            4.000000
# 50%                            6.000000
# 75%                            8.000000
# max                            8.000000
#
#        ha_quanto_tempo_voce_trabalha_em_shopping  em_qual_area_voce_trabalha  \
# count                                  95.000000                   95.000000
# mean                                    2.873684                    1.442105
# std                                     1.638903                    1.088780
# min                                     1.000000                    1.000000
# 25%                                     1.000000                    1.000000
# 50%                                     3.000000                    1.000000
# 75%                                     4.000000                    1.000000
# max                                     6.000000                    5.000000
#
#        quantas_horas_por_semana_voce_trabalha_no_total  \
# count                                        95.000000
# mean                                          4.989474
# std                                           1.491071
# min                                           1.000000
# 25%                                           5.000000
# 50%                                           6.000000
# 75%                                           6.000000
# max                                           6.000000
#
#        voce_tem_outro_trabalho  voce_possui_dependentes_financeiros  ...  \
# count                95.000000                            95.000000  ...
# mean                  1.915789                             1.515789  ...
# std                   0.279177                             0.502402  ...
# min                   1.000000                             1.000000  ...
# 25%                   2.000000                             1.000000  ...
# 50%                   2.000000                             2.000000  ...
# 75%                   2.000000                             2.000000  ...
# max                   2.000000                             2.000000  ...
#
#        2_22_comportamentos_incorretos_e_ou_inadequados_de_colegas_de_tr  \
# count                                          95.000000
# mean                                            1.747368
# std                                             1.344559
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             4.000000
#
#        2_23_falta_de_tempo_para_estar_com_a_familia_amigos  \
# count                                          95.000000
# mean                                            2.621053
# std                                             1.400448
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             4.000000
#
#        2_24_o_favoritismo_e_ou_discriminacao_encobertos_no_meu_local_de  \
# count                                          95.000000
# mean                                            1.905263
# std                                             1.480897
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             4.000000
#
#        com_que_frequencia_voce_consegue_passar_tempo_de_qualidade_com_f  \
# count                                          95.000000
# mean                                            1.800000
# std                                             1.037591
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             4.000000
#
#        com_que_frequencia_voce_tem_acesso_a_atividades_de_lazer_como_le  \
# count                                          95.000000
# mean                                            1.715789
# std                                             0.985676
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             4.000000
#
#        com_que_frequencia_voce_consegue_praticar_exercicios_fisicos  \
# count                                          95.000000
# mean                                            1.715789
# std                                             1.411677
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                             4.000000
#
#        com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_  \
# count                                          95.000000
# mean                                            1.336842
# std                                             1.077927
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             4.000000
#
#        com_que_frequencia_voce_consegue_dedicar_tempo_aos_estudos  \
# count                                          95.000000
# mean                                            1.452632
# std                                             1.227074
# min                                             0.000000
# 25%                                             0.500000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             4.000000
#
#        com_que_frequencia_voce_consegue_realizar_as_atividades_domestic  \
# count                                          95.000000
# mean                                            1.989474
# std                                             1.056839
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             4.000000
#
#        com_que_frequencia_voce_consegue_descansar_o_suficiente_no_seu_c
# count                                          95.000000
# mean                                            1.463158
# std                                             1.029465
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             4.000000
#
# [8 rows x 44 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95 entries, 0 to 105
# Data columns (total 44 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   qual_a_sua_idade                                                  95 non-null     int64
#  1   como_voce_se_identifica                                           95 non-null     int64
#  2   qual_e_a_sua_identidade_de_genero                                 95 non-null     float64
#  3   qual_e_a_sua_sexualidade                                          95 non-null     int64
#  4   qual_o_seu_nivel_de_escolaridade                                  95 non-null     float64
#  5   ha_quanto_tempo_voce_trabalha_em_shopping                         95 non-null     int64
#  6   em_qual_area_voce_trabalha                                        95 non-null     int64
#  7   quantas_horas_por_semana_voce_trabalha_no_total                   95 non-null     int64
#  8   voce_tem_outro_trabalho                                           95 non-null     int64
#  9   voce_possui_dependentes_financeiros                               95 non-null     int64
#  10  sua_residencia_e                                                  95 non-null     int64
#  11  qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho       95 non-null     int64
#  12  1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me    95 non-null     int64
#  13  2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c  95 non-null     float64
#  14  2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte  95 non-null     int64
#  15  2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma  95 non-null     int64
#  16  2_4_conflitos_e_problemas_com_colegas_de_trabalho                 95 non-null     float64
#  17  2_5_trabalhar_muitas_horas_seguidas                               95 non-null     int64
#  18  2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho     95 non-null     int64
#  19  2_7_falta_de_condicoes_de_trabalho                                95 non-null     float64
#  20  2_8_incompreensao_face_ao_nosso_trabalho_por_parte_das_pessoas_a  95 non-null     int64
#  21  2_9_falta_de_materiais_e_equipamentos_para_realizar_o_meu_trabal  95 non-null     float64
#  22  2_10_o_excesso_de_trabalho_e_ou_tarefas_de_carater_burocratico    95 non-null     int64
#  23  2_11_ter_de_realizar_muitas_horas_seguidas_de_trabalho            95 non-null     int64
#  24  2_12_conflitos_e_problemas_com_superiores_hierarquicos            95 non-null     float64
#  25  2_13_cumprir_com_aquilo_que_e_esperado_pelas_pessoas_a_quem_pres  95 non-null     float64
#  26  2_14_falta_de_tempo_para_dar_apoio_e_conviver_com_a_minha_famili  95 non-null     float64
#  27  2_15_falta_de_perspectivas_de_progressao_na_carreira              95 non-null     float64
#  28  2_16_a_sobrecarga_ou_excesso_de_trabalho                          95 non-null     float64
#  29  2_17_os_conflitos_interpessoais_com_outros_colegas_de_trabalho    95 non-null     float64
#  30  2_18_falta_de_meios_e_condicoes_de_trabalho                       95 non-null     float64
#  31  2_19_salario_inadequado_insuficiente                              95 non-null     float64
#  32  2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meus_superiores       95 non-null     float64
#  33  2_21_nivel_de_exigencia_das_pessoas_a_quem_presto_os_meus_servic  95 non-null     float64
#  34  2_22_comportamentos_incorretos_e_ou_inadequados_de_colegas_de_tr  95 non-null     float64
#  35  2_23_falta_de_tempo_para_estar_com_a_familia_amigos               95 non-null     int64
#  36  2_24_o_favoritismo_e_ou_discriminacao_encobertos_no_meu_local_de  95 non-null     int64
#  37  com_que_frequencia_voce_consegue_passar_tempo_de_qualidade_com_f  95 non-null     int64
#  38  com_que_frequencia_voce_tem_acesso_a_atividades_de_lazer_como_le  95 non-null     int64
#  39  com_que_frequencia_voce_consegue_praticar_exercicios_fisicos      95 non-null     int64
#  40  com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_  95 non-null     int64
#  41  com_que_frequencia_voce_consegue_dedicar_tempo_aos_estudos        95 non-null     int64
#  42  com_que_frequencia_voce_consegue_realizar_as_atividades_domestic  95 non-null     int64
#  43  com_que_frequencia_voce_consegue_descansar_o_suficiente_no_seu_c  95 non-null     int64
# dtypes: float64(17), int64(27)
# memory usage: 33.4 KB

# %%
import scipy

# Correlações de Pearson

df_final.corr()
# Out:
#                                                     qual_a_sua_idade  \
# qual_a_sua_idade                                            1.000000
# como_voce_se_identifica                                     0.219570
# qual_e_a_sua_identidade_de_genero                           0.019562
# qual_e_a_sua_sexualidade                                   -0.139718
# qual_o_seu_nivel_de_escolaridade                           -0.287311
# ha_quanto_tempo_voce_trabalha_em_shopping                   0.634019
# em_qual_area_voce_trabalha                                 -0.237347
# quantas_horas_por_semana_voce_trabalha_no_total             0.309825
# voce_tem_outro_trabalho                                     0.022646
# voce_possui_dependentes_financeiros                        -0.418640
# sua_residencia_e                                            0.035986
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...          0.275157
# 1_1_em_termos_gerais_a_minha_atividade_profissi...          0.020233
# 2_1_a_falta_de_possibilidades_de_desenvolviment...         -0.030926
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...         -0.164560
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...          0.083555
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho           0.090534
# 2_5_trabalhar_muitas_horas_seguidas                        -0.047007
# 2_6_viver_com_os_recursos_financeiros_salario_d...          0.039261
# 2_7_falta_de_condicoes_de_trabalho                          0.043610
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...         -0.104861
# 2_9_falta_de_materiais_e_equipamentos_para_real...          0.170008
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...          0.011366
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...          0.001672
# 2_12_conflitos_e_problemas_com_superiores_hiera...          0.057800
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...          0.055761
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...          0.088027
# 2_15_falta_de_perspectivas_de_progressao_na_car...         -0.021142
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                   -0.039455
# 2_17_os_conflitos_interpessoais_com_outros_cole...          0.137851
# 2_18_falta_de_meios_e_condicoes_de_trabalho                 0.270654
# 2_19_salario_inadequado_insuficiente                        0.151294
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...          0.032413
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...         -0.041628
# 2_22_comportamentos_incorretos_e_ou_inadequados...          0.046013
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...          0.089240
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...         -0.016924
# com_que_frequencia_voce_consegue_passar_tempo_d...         -0.161250
# com_que_frequencia_voce_tem_acesso_a_atividades...         -0.163329
# com_que_frequencia_voce_consegue_praticar_exerc...         -0.038067
# com_que_frequencia_voce_consegue_ir_ao_medico_p...         -0.053310
# com_que_frequencia_voce_consegue_dedicar_tempo_...         -0.176280
# com_que_frequencia_voce_consegue_realizar_as_at...          0.051489
# com_que_frequencia_voce_consegue_descansar_o_su...         -0.012940
#
#                                                     como_voce_se_identifica  \
# qual_a_sua_idade                                                   0.219570
# como_voce_se_identifica                                            1.000000
# qual_e_a_sua_identidade_de_genero                                  0.163187
# qual_e_a_sua_sexualidade                                          -0.164888
# qual_o_seu_nivel_de_escolaridade                                  -0.314365
# ha_quanto_tempo_voce_trabalha_em_shopping                          0.147317
# em_qual_area_voce_trabalha                                         0.103446
# quantas_horas_por_semana_voce_trabalha_no_total                    0.248727
# voce_tem_outro_trabalho                                            0.040121
# voce_possui_dependentes_financeiros                               -0.142437
# sua_residencia_e                                                   0.033471
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                 0.175012
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                -0.078799
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                -0.000559
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                -0.264574
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                 0.003437
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                 -0.014848
# 2_5_trabalhar_muitas_horas_seguidas                               -0.102981
# 2_6_viver_com_os_recursos_financeiros_salario_d...                -0.141129
# 2_7_falta_de_condicoes_de_trabalho                                -0.053971
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                -0.167799
# 2_9_falta_de_materiais_e_equipamentos_para_real...                -0.098064
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                -0.083850
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                -0.184263
# 2_12_conflitos_e_problemas_com_superiores_hiera...                -0.053781
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                -0.153673
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                 0.038984
# 2_15_falta_de_perspectivas_de_progressao_na_car...                -0.097924
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                          -0.049201
# 2_17_os_conflitos_interpessoais_com_outros_cole...                 0.031190
# 2_18_falta_de_meios_e_condicoes_de_trabalho                       -0.036385
# 2_19_salario_inadequado_insuficiente                              -0.075031
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                -0.120855
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                -0.139559
# 2_22_comportamentos_incorretos_e_ou_inadequados...                -0.045355
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                 0.052876
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                -0.109251
# com_que_frequencia_voce_consegue_passar_tempo_d...                 0.045579
# com_que_frequencia_voce_tem_acesso_a_atividades...                -0.096590
# com_que_frequencia_voce_consegue_praticar_exerc...                 0.033060
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                 0.013277
# com_que_frequencia_voce_consegue_dedicar_tempo_...                -0.200817
# com_que_frequencia_voce_consegue_realizar_as_at...                -0.018253
# com_que_frequencia_voce_consegue_descansar_o_su...                 0.123913
#
#                                                     qual_e_a_sua_identidade_de_genero  \
# qual_a_sua_idade                                                             0.019562
# como_voce_se_identifica                                                      0.163187
# qual_e_a_sua_identidade_de_genero                                            1.000000
# qual_e_a_sua_sexualidade                                                     0.117378
# qual_o_seu_nivel_de_escolaridade                                            -0.208080
# ha_quanto_tempo_voce_trabalha_em_shopping                                    0.048316
# em_qual_area_voce_trabalha                                                  -0.185916
# quantas_horas_por_semana_voce_trabalha_no_total                              0.030598
# voce_tem_outro_trabalho                                                      0.236680
# voce_possui_dependentes_financeiros                                         -0.265126
# sua_residencia_e                                                            -0.040745
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                           0.213933
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                          -0.111992
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                          -0.137532
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                          -0.069490
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                          -0.144820
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                           -0.206470
# 2_5_trabalhar_muitas_horas_seguidas                                         -0.107560
# 2_6_viver_com_os_recursos_financeiros_salario_d...                          -0.087660
# 2_7_falta_de_condicoes_de_trabalho                                          -0.126344
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                          -0.094274
# 2_9_falta_de_materiais_e_equipamentos_para_real...                          -0.207755
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                          -0.077974
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                          -0.155286
# 2_12_conflitos_e_problemas_com_superiores_hiera...                          -0.193201
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                          -0.030472
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                          -0.206226
# 2_15_falta_de_perspectivas_de_progressao_na_car...                          -0.170001
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                    -0.069660
# 2_17_os_conflitos_interpessoais_com_outros_cole...                          -0.159866
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                 -0.222311
# 2_19_salario_inadequado_insuficiente                                        -0.176541
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                          -0.187093
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                          -0.103659
# 2_22_comportamentos_incorretos_e_ou_inadequados...                          -0.208272
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                          -0.157647
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                          -0.099507
# com_que_frequencia_voce_consegue_passar_tempo_d...                           0.057617
# com_que_frequencia_voce_tem_acesso_a_atividades...                           0.117579
# com_que_frequencia_voce_consegue_praticar_exerc...                           0.046806
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                           0.170761
# com_que_frequencia_voce_consegue_dedicar_tempo_...                          -0.031625
# com_que_frequencia_voce_consegue_realizar_as_at...                           0.156305
# com_que_frequencia_voce_consegue_descansar_o_su...                           0.063166
#
#                                                     qual_e_a_sua_sexualidade  \
# qual_a_sua_idade                                                   -0.139718
# como_voce_se_identifica                                            -0.164888
# qual_e_a_sua_identidade_de_genero                                   0.117378
# qual_e_a_sua_sexualidade                                            1.000000
# qual_o_seu_nivel_de_escolaridade                                    0.201580
# ha_quanto_tempo_voce_trabalha_em_shopping                          -0.183592
# em_qual_area_voce_trabalha                                          0.001239
# quantas_horas_por_semana_voce_trabalha_no_total                    -0.260893
# voce_tem_outro_trabalho                                            -0.093807
# voce_possui_dependentes_financeiros                                 0.088146
# sua_residencia_e                                                    0.051502
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                 -0.015884
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                 -0.045957
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                 -0.115589
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                  0.021645
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                 -0.133382
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                  -0.208144
# 2_5_trabalhar_muitas_horas_seguidas                                -0.034729
# 2_6_viver_com_os_recursos_financeiros_salario_d...                 -0.025209
# 2_7_falta_de_condicoes_de_trabalho                                 -0.180802
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                 -0.124604
# 2_9_falta_de_materiais_e_equipamentos_para_real...                 -0.093240
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                  0.006964
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                 -0.004992
# 2_12_conflitos_e_problemas_com_superiores_hiera...                 -0.068906
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                  0.135523
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                 -0.151777
# 2_15_falta_de_perspectivas_de_progressao_na_car...                 -0.128767
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                           -0.122109
# 2_17_os_conflitos_interpessoais_com_outros_cole...                 -0.247333
# 2_18_falta_de_meios_e_condicoes_de_trabalho                        -0.266175
# 2_19_salario_inadequado_insuficiente                               -0.097143
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                 -0.268442
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                 -0.052980
# 2_22_comportamentos_incorretos_e_ou_inadequados...                 -0.249029
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                 -0.171834
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                 -0.013586
# com_que_frequencia_voce_consegue_passar_tempo_d...                  0.111143
# com_que_frequencia_voce_tem_acesso_a_atividades...                  0.057928
# com_que_frequencia_voce_consegue_praticar_exerc...                 -0.004936
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                 -0.061312
# com_que_frequencia_voce_consegue_dedicar_tempo_...                  0.083171
# com_que_frequencia_voce_consegue_realizar_as_at...                 -0.004360
# com_que_frequencia_voce_consegue_descansar_o_su...                 -0.000109
#
#                                                     qual_o_seu_nivel_de_escolaridade  \
# qual_a_sua_idade                                                           -0.287311
# como_voce_se_identifica                                                    -0.314365
# qual_e_a_sua_identidade_de_genero                                          -0.208080
# qual_e_a_sua_sexualidade                                                    0.201580
# qual_o_seu_nivel_de_escolaridade                                            1.000000
# ha_quanto_tempo_voce_trabalha_em_shopping                                  -0.158175
# em_qual_area_voce_trabalha                                                  0.013206
# quantas_horas_por_semana_voce_trabalha_no_total                            -0.114297
# voce_tem_outro_trabalho                                                    -0.030818
# voce_possui_dependentes_financeiros                                         0.308255
# sua_residencia_e                                                            0.054591
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                         -0.156346
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                          0.062798
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                          0.137084
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                          0.088426
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                          0.021017
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                          -0.073623
# 2_5_trabalhar_muitas_horas_seguidas                                         0.206360
# 2_6_viver_com_os_recursos_financeiros_salario_d...                          0.192113
# 2_7_falta_de_condicoes_de_trabalho                                         -0.046663
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                          0.067978
# 2_9_falta_de_materiais_e_equipamentos_para_real...                          0.043468
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                          0.081462
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                          0.199804
# 2_12_conflitos_e_problemas_com_superiores_hiera...                          0.073204
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                          0.150669
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                          0.053911
# 2_15_falta_de_perspectivas_de_progressao_na_car...                          0.075024
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                    0.105863
# 2_17_os_conflitos_interpessoais_com_outros_cole...                         -0.054524
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                -0.024982
# 2_19_salario_inadequado_insuficiente                                        0.110591
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                          0.036368
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                          0.104837
# 2_22_comportamentos_incorretos_e_ou_inadequados...                          0.043259
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                          0.076290
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                          0.049224
# com_que_frequencia_voce_consegue_passar_tempo_d...                          0.046402
# com_que_frequencia_voce_tem_acesso_a_atividades...                          0.136672
# com_que_frequencia_voce_consegue_praticar_exerc...                          0.075600
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                          0.005959
# com_que_frequencia_voce_consegue_dedicar_tempo_...                          0.438034
# com_que_frequencia_voce_consegue_realizar_as_at...                         -0.193043
# com_que_frequencia_voce_consegue_descansar_o_su...                         -0.122615
#
#                                                     ha_quanto_tempo_voce_trabalha_em_shopping  \
# qual_a_sua_idade                                                                     0.634019
# como_voce_se_identifica                                                              0.147317
# qual_e_a_sua_identidade_de_genero                                                    0.048316
# qual_e_a_sua_sexualidade                                                            -0.183592
# qual_o_seu_nivel_de_escolaridade                                                    -0.158175
# ha_quanto_tempo_voce_trabalha_em_shopping                                            1.000000
# em_qual_area_voce_trabalha                                                          -0.320118
# quantas_horas_por_semana_voce_trabalha_no_total                                      0.265003
# voce_tem_outro_trabalho                                                              0.023006
# voce_possui_dependentes_financeiros                                                 -0.436837
# sua_residencia_e                                                                     0.267481
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                                   0.249679
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                                   0.003886
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                                  -0.001227
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                                  -0.016675
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                                   0.031107
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                                    0.040411
# 2_5_trabalhar_muitas_horas_seguidas                                                 -0.058163
# 2_6_viver_com_os_recursos_financeiros_salario_d...                                  -0.005682
# 2_7_falta_de_condicoes_de_trabalho                                                  -0.060141
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                                  -0.110551
# 2_9_falta_de_materiais_e_equipamentos_para_real...                                   0.063112
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                                  -0.053444
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                                  -0.066768
# 2_12_conflitos_e_problemas_com_superiores_hiera...                                  -0.009709
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                                   0.015881
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                                   0.039557
# 2_15_falta_de_perspectivas_de_progressao_na_car...                                  -0.131288
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                            -0.084441
# 2_17_os_conflitos_interpessoais_com_outros_cole...                                   0.053562
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                          0.055934
# 2_19_salario_inadequado_insuficiente                                                 0.051645
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                                  -0.029714
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                                  -0.074543
# 2_22_comportamentos_incorretos_e_ou_inadequados...                                  -0.019463
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                                  -0.007172
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                                  -0.066348
# com_que_frequencia_voce_consegue_passar_tempo_d...                                   0.016265
# com_que_frequencia_voce_tem_acesso_a_atividades...                                   0.023638
# com_que_frequencia_voce_consegue_praticar_exerc...                                   0.172842
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                                   0.174887
# com_que_frequencia_voce_consegue_dedicar_tempo_...                                   0.034022
# com_que_frequencia_voce_consegue_realizar_as_at...                                   0.072928
# com_que_frequencia_voce_consegue_descansar_o_su...                                   0.072876
#
#                                                     em_qual_area_voce_trabalha  \
# qual_a_sua_idade                                                     -0.237347
# como_voce_se_identifica                                               0.103446
# qual_e_a_sua_identidade_de_genero                                    -0.185916
# qual_e_a_sua_sexualidade                                              0.001239
# qual_o_seu_nivel_de_escolaridade                                      0.013206
# ha_quanto_tempo_voce_trabalha_em_shopping                            -0.320118
# em_qual_area_voce_trabalha                                            1.000000
# quantas_horas_por_semana_voce_trabalha_no_total                      -0.154373
# voce_tem_outro_trabalho                                              -0.296200
# voce_possui_dependentes_financeiros                                   0.220482
# sua_residencia_e                                                      0.060446
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                   -0.182869
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                   -0.025717
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                    0.050345
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                    0.050594
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                    0.055833
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                     0.103515
# 2_5_trabalhar_muitas_horas_seguidas                                  -0.136532
# 2_6_viver_com_os_recursos_financeiros_salario_d...                   -0.039828
# 2_7_falta_de_condicoes_de_trabalho                                    0.089289
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                    0.166408
# 2_9_falta_de_materiais_e_equipamentos_para_real...                    0.123740
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                    0.198329
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                    0.001523
# 2_12_conflitos_e_problemas_com_superiores_hiera...                    0.036837
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                    0.020918
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                   -0.012965
# 2_15_falta_de_perspectivas_de_progressao_na_car...                    0.168894
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                              0.016102
# 2_17_os_conflitos_interpessoais_com_outros_cole...                    0.022903
# 2_18_falta_de_meios_e_condicoes_de_trabalho                           0.096223
# 2_19_salario_inadequado_insuficiente                                 -0.019060
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                    0.087791
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                    0.017594
# 2_22_comportamentos_incorretos_e_ou_inadequados...                    0.033504
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                    0.013366
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                    0.026253
# com_que_frequencia_voce_consegue_passar_tempo_d...                    0.116769
# com_que_frequencia_voce_tem_acesso_a_atividades...                    0.128241
# com_que_frequencia_voce_consegue_praticar_exerc...                    0.110306
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                   -0.073852
# com_que_frequencia_voce_consegue_dedicar_tempo_...                    0.015842
# com_que_frequencia_voce_consegue_realizar_as_at...                   -0.042139
# com_que_frequencia_voce_consegue_descansar_o_su...                    0.138072
#
#                                                     quantas_horas_por_semana_voce_trabalha_no_total  \
# qual_a_sua_idade                                                                           0.309825
# como_voce_se_identifica                                                                    0.248727
# qual_e_a_sua_identidade_de_genero                                                          0.030598
# qual_e_a_sua_sexualidade                                                                  -0.260893
# qual_o_seu_nivel_de_escolaridade                                                          -0.114297
# ha_quanto_tempo_voce_trabalha_em_shopping                                                  0.265003
# em_qual_area_voce_trabalha                                                                -0.154373
# quantas_horas_por_semana_voce_trabalha_no_total                                            1.000000
# voce_tem_outro_trabalho                                                                    0.151185
# voce_possui_dependentes_financeiros                                                       -0.177290
# sua_residencia_e                                                                          -0.007481
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                                         0.322952
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                                         0.217931
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                                         0.194265
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                                         0.030213
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                                         0.509967
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                                          0.233736
# 2_5_trabalhar_muitas_horas_seguidas                                                        0.436928
# 2_6_viver_com_os_recursos_financeiros_salario_d...                                         0.303629
# 2_7_falta_de_condicoes_de_trabalho                                                         0.153015
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                                         0.141763
# 2_9_falta_de_materiais_e_equipamentos_para_real...                                         0.128108
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                                         0.242820
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                                         0.246851
# 2_12_conflitos_e_problemas_com_superiores_hiera...                                         0.196816
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                                         0.248748
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                                         0.439384
# 2_15_falta_de_perspectivas_de_progressao_na_car...                                         0.198492
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                                   0.261635
# 2_17_os_conflitos_interpessoais_com_outros_cole...                                         0.236476
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                                0.288734
# 2_19_salario_inadequado_insuficiente                                                       0.286681
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                                         0.135344
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                                         0.179855
# 2_22_comportamentos_incorretos_e_ou_inadequados...                                         0.088867
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                                         0.471864
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                                         0.081446
# com_que_frequencia_voce_consegue_passar_tempo_d...                                        -0.317680
# com_que_frequencia_voce_tem_acesso_a_atividades...                                        -0.226446
# com_que_frequencia_voce_consegue_praticar_exerc...                                        -0.041869
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                                        -0.057340
# com_que_frequencia_voce_consegue_dedicar_tempo_...                                        -0.125284
# com_que_frequencia_voce_consegue_realizar_as_at...                                        -0.141841
# com_que_frequencia_voce_consegue_descansar_o_su...                                        -0.232426
#
#                                                     voce_tem_outro_trabalho  \
# qual_a_sua_idade                                                   0.022646
# como_voce_se_identifica                                            0.040121
# qual_e_a_sua_identidade_de_genero                                  0.236680
# qual_e_a_sua_sexualidade                                          -0.093807
# qual_o_seu_nivel_de_escolaridade                                  -0.030818
# ha_quanto_tempo_voce_trabalha_em_shopping                          0.023006
# em_qual_area_voce_trabalha                                        -0.296200
# quantas_horas_por_semana_voce_trabalha_no_total                    0.151185
# voce_tem_outro_trabalho                                            1.000000
# voce_possui_dependentes_financeiros                                0.009581
# sua_residencia_e                                                  -0.167812
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                 0.057524
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                -0.052947
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                -0.016212
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                -0.016825
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                 0.171854
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                 -0.112463
# 2_5_trabalhar_muitas_horas_seguidas                               -0.015183
# 2_6_viver_com_os_recursos_financeiros_salario_d...                 0.105798
# 2_7_falta_de_condicoes_de_trabalho                                 0.080855
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                 0.048073
# 2_9_falta_de_materiais_e_equipamentos_para_real...                -0.003219
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                -0.012425
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                 0.035633
# 2_12_conflitos_e_problemas_com_superiores_hiera...                 0.008520
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                 0.023308
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                 0.049351
# 2_15_falta_de_perspectivas_de_progressao_na_car...                -0.034086
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                           0.121470
# 2_17_os_conflitos_interpessoais_com_outros_cole...                -0.072181
# 2_18_falta_de_meios_e_condicoes_de_trabalho                       -0.064499
# 2_19_salario_inadequado_insuficiente                               0.037654
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                 0.017782
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                 0.036594
# 2_22_comportamentos_incorretos_e_ou_inadequados...                -0.198983
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                 0.080770
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                -0.070965
# com_que_frequencia_voce_consegue_passar_tempo_d...                 0.014690
# com_que_frequencia_voce_tem_acesso_a_atividades...                -0.049240
# com_que_frequencia_voce_consegue_praticar_exerc...                -0.142355
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                 0.024560
# com_que_frequencia_voce_consegue_dedicar_tempo_...                -0.042822
# com_que_frequencia_voce_consegue_realizar_as_at...                 0.069077
# com_que_frequencia_voce_consegue_descansar_o_su...                 0.063121
#
#                                                     voce_possui_dependentes_financeiros  \
# qual_a_sua_idade                                                              -0.418640
# como_voce_se_identifica                                                       -0.142437
# qual_e_a_sua_identidade_de_genero                                             -0.265126
# qual_e_a_sua_sexualidade                                                       0.088146
# qual_o_seu_nivel_de_escolaridade                                               0.308255
# ha_quanto_tempo_voce_trabalha_em_shopping                                     -0.436837
# em_qual_area_voce_trabalha                                                     0.220482
# quantas_horas_por_semana_voce_trabalha_no_total                               -0.177290
# voce_tem_outro_trabalho                                                        0.009581
# voce_possui_dependentes_financeiros                                            1.000000
# sua_residencia_e                                                              -0.135435
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                            -0.251065
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                            -0.083959
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                             0.124120
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                             0.006800
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                             0.001935
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                             -0.048058
# 2_5_trabalhar_muitas_horas_seguidas                                            0.040027
# 2_6_viver_com_os_recursos_financeiros_salario_d...                             0.008987
# 2_7_falta_de_condicoes_de_trabalho                                            -0.077508
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                             0.136906
# 2_9_falta_de_materiais_e_equipamentos_para_real...                            -0.045046
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                            -0.056100
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                             0.072603
# 2_12_conflitos_e_problemas_com_superiores_hiera...                            -0.023182
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                            -0.055045
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                            -0.030115
# 2_15_falta_de_perspectivas_de_progressao_na_car...                             0.057700
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                       0.074196
# 2_17_os_conflitos_interpessoais_com_outros_cole...                            -0.113187
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                   -0.071682
# 2_19_salario_inadequado_insuficiente                                           0.000361
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                            -0.028860
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                            -0.011862
# 2_22_comportamentos_incorretos_e_ou_inadequados...                            -0.041278
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                            -0.036766
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                            -0.133806
# com_que_frequencia_voce_consegue_passar_tempo_d...                             0.097957
# com_que_frequencia_voce_tem_acesso_a_atividades...                             0.084347
# com_que_frequencia_voce_consegue_praticar_exerc...                             0.028894
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                            -0.049214
# com_que_frequencia_voce_consegue_dedicar_tempo_...                             0.152220
# com_que_frequencia_voce_consegue_realizar_as_at...                            -0.129918
# com_que_frequencia_voce_consegue_descansar_o_su...                             0.006279
#
#                                                     ...  \
# qual_a_sua_idade                                    ...
# como_voce_se_identifica                             ...
# qual_e_a_sua_identidade_de_genero                   ...
# qual_e_a_sua_sexualidade                            ...
# qual_o_seu_nivel_de_escolaridade                    ...
# ha_quanto_tempo_voce_trabalha_em_shopping           ...
# em_qual_area_voce_trabalha                          ...
# quantas_horas_por_semana_voce_trabalha_no_total     ...
# voce_tem_outro_trabalho                             ...
# voce_possui_dependentes_financeiros                 ...
# sua_residencia_e                                    ...
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...  ...
# 1_1_em_termos_gerais_a_minha_atividade_profissi...  ...
# 2_1_a_falta_de_possibilidades_de_desenvolviment...  ...
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...  ...
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...  ...
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho   ...
# 2_5_trabalhar_muitas_horas_seguidas                 ...
# 2_6_viver_com_os_recursos_financeiros_salario_d...  ...
# 2_7_falta_de_condicoes_de_trabalho                  ...
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...  ...
# 2_9_falta_de_materiais_e_equipamentos_para_real...  ...
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...  ...
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...  ...
# 2_12_conflitos_e_problemas_com_superiores_hiera...  ...
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...  ...
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...  ...
# 2_15_falta_de_perspectivas_de_progressao_na_car...  ...
# 2_16_a_sobrecarga_ou_excesso_de_trabalho            ...
# 2_17_os_conflitos_interpessoais_com_outros_cole...  ...
# 2_18_falta_de_meios_e_condicoes_de_trabalho         ...
# 2_19_salario_inadequado_insuficiente                ...
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...  ...
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...  ...
# 2_22_comportamentos_incorretos_e_ou_inadequados...  ...
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...  ...
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...  ...
# com_que_frequencia_voce_consegue_passar_tempo_d...  ...
# com_que_frequencia_voce_tem_acesso_a_atividades...  ...
# com_que_frequencia_voce_consegue_praticar_exerc...  ...
# com_que_frequencia_voce_consegue_ir_ao_medico_p...  ...
# com_que_frequencia_voce_consegue_dedicar_tempo_...  ...
# com_que_frequencia_voce_consegue_realizar_as_at...  ...
# com_que_frequencia_voce_consegue_descansar_o_su...  ...
#
#                                                     2_22_comportamentos_incorretos_e_ou_inadequados_de_colegas_de_tr  \
# qual_a_sua_idade                                                                             0.046013
# como_voce_se_identifica                                                                     -0.045355
# qual_e_a_sua_identidade_de_genero                                                           -0.208272
# qual_e_a_sua_sexualidade                                                                    -0.249029
# qual_o_seu_nivel_de_escolaridade                                                             0.043259
# ha_quanto_tempo_voce_trabalha_em_shopping                                                   -0.019463
# em_qual_area_voce_trabalha                                                                   0.033504
# quantas_horas_por_semana_voce_trabalha_no_total                                              0.088867
# voce_tem_outro_trabalho                                                                     -0.198983
# voce_possui_dependentes_financeiros                                                         -0.041278
# sua_residencia_e                                                                            -0.104531
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                                          -0.096363
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                                           0.467984
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                                           0.331004
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                                           0.374200
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                                           0.350520
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                                            0.671647
# 2_5_trabalhar_muitas_horas_seguidas                                                          0.450227
# 2_6_viver_com_os_recursos_financeiros_salario_d...                                           0.331748
# 2_7_falta_de_condicoes_de_trabalho                                                           0.399842
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                                           0.398016
# 2_9_falta_de_materiais_e_equipamentos_para_real...                                           0.350125
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                                           0.451809
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                                           0.410625
# 2_12_conflitos_e_problemas_com_superiores_hiera...                                           0.503688
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                                           0.286742
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                                           0.424900
# 2_15_falta_de_perspectivas_de_progressao_na_car...                                           0.470583
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                                     0.444765
# 2_17_os_conflitos_interpessoais_com_outros_cole...                                           0.735200
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                                  0.647698
# 2_19_salario_inadequado_insuficiente                                                         0.446044
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                                           0.556706
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                                           0.473938
# 2_22_comportamentos_incorretos_e_ou_inadequados...                                           1.000000
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                                           0.406243
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                                           0.591586
# com_que_frequencia_voce_consegue_passar_tempo_d...                                          -0.234864
# com_que_frequencia_voce_tem_acesso_a_atividades...                                          -0.175160
# com_que_frequencia_voce_consegue_praticar_exerc...                                           0.001003
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                                          -0.315007
# com_que_frequencia_voce_consegue_dedicar_tempo_...                                          -0.265248
# com_que_frequencia_voce_consegue_realizar_as_at...                                          -0.263922
# com_que_frequencia_voce_consegue_descansar_o_su...                                          -0.368021
#
#                                                     2_23_falta_de_tempo_para_estar_com_a_familia_amigos  \
# qual_a_sua_idade                                                                             0.089240
# como_voce_se_identifica                                                                      0.052876
# qual_e_a_sua_identidade_de_genero                                                           -0.157647
# qual_e_a_sua_sexualidade                                                                    -0.171834
# qual_o_seu_nivel_de_escolaridade                                                             0.076290
# ha_quanto_tempo_voce_trabalha_em_shopping                                                   -0.007172
# em_qual_area_voce_trabalha                                                                   0.013366
# quantas_horas_por_semana_voce_trabalha_no_total                                              0.471864
# voce_tem_outro_trabalho                                                                      0.080770
# voce_possui_dependentes_financeiros                                                         -0.036766
# ...
#
#                                                     com_que_frequencia_voce_consegue_dedicar_tempo_aos_estudos  \
# qual_a_sua_idade                                                                            -0.176280
# como_voce_se_identifica                                                                     -0.200817
# qual_e_a_sua_identidade_de_genero                                                           -0.031625
# qual_e_a_sua_sexualidade                                                                     0.083171
# qual_o_seu_nivel_de_escolaridade                                                             0.438034
# ha_quanto_tempo_voce_trabalha_em_shopping                                                    0.034022
# em_qual_area_voce_trabalha                                                                   0.015842
# quantas_horas_por_semana_voce_trabalha_no_total                                             -0.125284
# voce_tem_outro_trabalho                                                                     -0.042822
# voce_possui_dependentes_financeiros                                                          0.152220
# sua_residencia_e                                                                             0.218169
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                                          -0.089960
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                                          -0.138775
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                                          -0.066802
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                                          -0.132326
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                                          -0.248637
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                                           -0.280834
# 2_5_trabalhar_muitas_horas_seguidas                                                         -0.148378
# 2_6_viver_com_os_recursos_financeiros_salario_d...                                          -0.134841
# 2_7_falta_de_condicoes_de_trabalho                                                          -0.232034
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                                          -0.147653
# 2_9_falta_de_materiais_e_equipamentos_para_real...                                          -0.109129
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                                          -0.186224
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                                          -0.271585
# 2_12_conflitos_e_problemas_com_superiores_hiera...                                          -0.181075
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                                          -0.117989
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                                          -0.322925
# 2_15_falta_de_perspectivas_de_progressao_na_car...                                          -0.268698
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                                    -0.337911
# 2_17_os_conflitos_interpessoais_com_outros_cole...                                          -0.302650
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                                 -0.325507
# 2_19_salario_inadequado_insuficiente                                                        -0.189872
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                                          -0.251285
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                                          -0.202939
# 2_22_comportamentos_incorretos_e_ou_inadequados...                                          -0.265248
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                                          -0.307707
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                                          -0.204470
# com_que_frequencia_voce_consegue_passar_tempo_d...                                           0.322524
# com_que_frequencia_voce_tem_acesso_a_atividades...                                           0.424135
# com_que_frequencia_voce_consegue_praticar_exerc...                                           0.412830
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                                           0.438464
# com_que_frequencia_voce_consegue_dedicar_tempo_...                                           1.000000
# com_que_frequencia_voce_consegue_realizar_as_at...                                           0.233408
# com_que_frequencia_voce_consegue_descansar_o_su...                                           0.413363
#
#                                                     com_que_frequencia_voce_consegue_realizar_as_atividades_domestic  \
# qual_a_sua_idade                                                                             0.051489
# como_voce_se_identifica                                                                     -0.018253
# qual_e_a_sua_identidade_de_genero                                                            0.156305
# qual_e_a_sua_sexualidade                                                                    -0.004360
# qual_o_seu_nivel_de_escolaridade                                                            -0.193043
# ha_quanto_tempo_voce_trabalha_em_shopping                                                    0.072928
# em_qual_area_voce_trabalha                                                                  -0.042139
# quantas_horas_por_semana_voce_trabalha_no_total                                             -0.141841
# voce_tem_outro_trabalho                                                                      0.069077
# voce_possui_dependentes_financeiros                                                         -0.129918
# sua_residencia_e                                                                             0.009499
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                                          -0.013868
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                                          -0.394691
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                                          -0.250292
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                                          -0.302837
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                                          -0.424210
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                                           -0.236403
# 2_5_trabalhar_muitas_horas_seguidas                                                         -0.358268
# 2_6_viver_com_os_recursos_financeiros_salario_d...                                          -0.264970
# 2_7_falta_de_condicoes_de_trabalho                                                          -0.188315
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                                          -0.363510
# 2_9_falta_de_materiais_e_equipamentos_para_real...                                          -0.157089
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                                          -0.296638
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                                          -0.412598
# 2_12_conflitos_e_problemas_com_superiores_hiera...                                          -0.260532
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                                          -0.264754
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                                          -0.390617
# 2_15_falta_de_perspectivas_de_progressao_na_car...                                          -0.187254
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                                    -0.434734
# 2_17_os_conflitos_interpessoais_com_outros_cole...                                          -0.245353
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                                 -0.196714
# 2_19_salario_inadequado_insuficiente                                                        -0.320524
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                                          -0.283635
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                                          -0.343171
# 2_22_comportamentos_incorretos_e_ou_inadequados...                                          -0.263922
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                                          -0.369302
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                                          -0.252145
# com_que_frequencia_voce_consegue_passar_tempo_d...                                           0.454028
# com_que_frequencia_voce_tem_acesso_a_atividades...                                           0.548569
# com_que_frequencia_voce_consegue_praticar_exerc...                                           0.147717
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                                           0.404698
# com_que_frequencia_voce_consegue_dedicar_tempo_...                                           0.233408
# com_que_frequencia_voce_consegue_realizar_as_at...                                           1.000000
# com_que_frequencia_voce_consegue_descansar_o_su...                                           0.659657
#
#                                                     com_que_frequencia_voce_consegue_descansar_o_suficiente_no_seu_c
# qual_a_sua_idade                                                                            -0.012940
# como_voce_se_identifica                                                                      0.123913
# qual_e_a_sua_identidade_de_genero                                                            0.063166
# qual_e_a_sua_sexualidade                                                                    -0.000109
# qual_o_seu_nivel_de_escolaridade                                                            -0.122615
# ha_quanto_tempo_voce_trabalha_em_shopping                                                    0.072876
# em_qual_area_voce_trabalha                                                                   0.138072
# quantas_horas_por_semana_voce_trabalha_no_total                                             -0.232426
# voce_tem_outro_trabalho                                                                      0.063121
# voce_possui_dependentes_financeiros                                                          0.006279
# sua_residencia_e                                                                             0.126773
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...                                          -0.013858
# 1_1_em_termos_gerais_a_minha_atividade_profissi...                                          -0.469974
# 2_1_a_falta_de_possibilidades_de_desenvolviment...                                          -0.249620
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...                                          -0.280298
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...                                          -0.496857
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                                           -0.285795
# 2_5_trabalhar_muitas_horas_seguidas                                                         -0.464028
# 2_6_viver_com_os_recursos_financeiros_salario_d...                                          -0.340088
# 2_7_falta_de_condicoes_de_trabalho                                                          -0.216035
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...                                          -0.381324
# 2_9_falta_de_materiais_e_equipamentos_para_real...                                          -0.217614
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...                                          -0.389607
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...                                          -0.463833
# 2_12_conflitos_e_problemas_com_superiores_hiera...                                          -0.364660
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...                                          -0.350804
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...                                          -0.561110
# 2_15_falta_de_perspectivas_de_progressao_na_car...                                          -0.331316
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                                                    -0.544773
# 2_17_os_conflitos_interpessoais_com_outros_cole...                                          -0.389078
# 2_18_falta_de_meios_e_condicoes_de_trabalho                                                 -0.305303
# 2_19_salario_inadequado_insuficiente                                                        -0.323766
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...                                          -0.357388
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...                                          -0.463112
# 2_22_comportamentos_incorretos_e_ou_inadequados...                                          -0.368021
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...                                          -0.555828
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...                                          -0.403553
# com_que_frequencia_voce_consegue_passar_tempo_d...                                           0.555736
# com_que_frequencia_voce_tem_acesso_a_atividades...                                           0.592400
# com_que_frequencia_voce_consegue_praticar_exerc...                                           0.311149
# com_que_frequencia_voce_consegue_ir_ao_medico_p...                                           0.509813
# com_que_frequencia_voce_consegue_dedicar_tempo_...                                           0.413363
# com_que_frequencia_voce_consegue_realizar_as_at...                                           0.659657
# com_que_frequencia_voce_consegue_descansar_o_su...                                           1.000000
#
# [44 rows x 44 columns]

# %%
# Maiores correlações

corr_matrix = df_final.corr()

corr_matrix_no_self = corr_matrix.where(~np.eye(corr_matrix.shape[0], dtype=bool))

corr_unstacked = corr_matrix_no_self.abs().unstack()

corr_unstacked = corr_unstacked.drop_duplicates()

sorted_corrs = corr_unstacked.sort_values(ascending=False)

top_n = 10
print(sorted_corrs.head(top_n))
# Out:
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_com_a_minha_famili  2_23_falta_de_tempo_para_estar_com_a_familia_amigos                 0.890003
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho                 2_17_os_conflitos_interpessoais_com_outros_colegas_de_trabalho      0.863045
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma  2_14_falta_de_tempo_para_dar_apoio_e_conviver_com_a_minha_famili    0.817246
#                                                                   2_23_falta_de_tempo_para_estar_com_a_familia_amigos                 0.816470
# 2_8_incompreensao_face_ao_nosso_trabalho_por_parte_das_pessoas_a  2_21_nivel_de_exigencia_das_pessoas_a_quem_presto_os_meus_servic    0.784380
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_trabalho            2_16_a_sobrecarga_ou_excesso_de_trabalho                            0.783940
# 2_12_conflitos_e_problemas_com_superiores_hierarquicos            2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meus_superiores         0.765723
# 2_5_trabalhar_muitas_horas_seguidas                               2_11_ter_de_realizar_muitas_horas_seguidas_de_trabalho              0.761860
# 2_16_a_sobrecarga_ou_excesso_de_trabalho                          2_21_nivel_de_exigencia_das_pessoas_a_quem_presto_os_meus_servic    0.737434
# 2_17_os_conflitos_interpessoais_com_outros_colegas_de_trabalho    2_22_comportamentos_incorretos_e_ou_inadequados_de_colegas_de_tr    0.735200
# dtype: float64

# %%
df_final.apply(df.value_counts)
# Out:
#      qual_a_sua_idade  como_voce_se_identifica  \
# 0.0               NaN                      NaN
# 1.0              36.0                     26.0
# 2.0              23.0                      9.0
# 3.0              29.0                     59.0
# 4.0               7.0                      1.0
# 5.0               NaN                      NaN
# 6.0               NaN                      NaN
# 7.0               NaN                      NaN
# 8.0               NaN                      NaN
#
#      qual_e_a_sua_identidade_de_genero  qual_e_a_sua_sexualidade  \
# 0.0                                NaN                       NaN
# 1.0                               24.0                      66.0
# 2.0                                1.0                      10.0
# 3.0                               67.0                      16.0
# 4.0                                NaN                       1.0
# 5.0                                NaN                       1.0
# 6.0                                3.0                       1.0
# 7.0                                NaN                       NaN
# 8.0                                NaN                       NaN
#
#      qual_o_seu_nivel_de_escolaridade  \
# 0.0                               NaN
# 1.0                               1.0
# 2.0                               3.0
# 3.0                               2.0
# 4.0                              39.0
# 5.0                               NaN
# 6.0                              17.0
# 7.0                               7.0
# 8.0                              26.0
#
#      ha_quanto_tempo_voce_trabalha_em_shopping  em_qual_area_voce_trabalha  \
# 0.0                                        NaN                         NaN
# 1.0                                       27.0                        81.0
# 2.0                                       17.0                         NaN
# 3.0                                       18.0                         2.0
# 4.0                                       16.0                        10.0
# 5.0                                        8.0                         2.0
# 6.0                                        9.0                         NaN
# 7.0                                        NaN                         NaN
# 8.0                                        NaN                         NaN
#
#      quantas_horas_por_semana_voce_trabalha_no_total  voce_tem_outro_trabalho  \
# 0.0                                              NaN                      NaN
# 1.0                                              7.0                      8.0
# 2.0                                              4.0                     87.0
# 3.0                                              2.0                      NaN
# 4.0                                              5.0                      NaN
# 5.0                                             29.0                      NaN
# 6.0                                             48.0                      NaN
# 7.0                                              NaN                      NaN
# 8.0                                              NaN                      NaN
#
#      voce_possui_dependentes_financeiros  ...  \
# 0.0                                  NaN  ...
# 1.0                                 46.0  ...
# 2.0                                 49.0  ...
# 3.0                                  NaN  ...
# 4.0                                  NaN  ...
# 5.0                                  NaN  ...
# 6.0                                  NaN  ...
# 7.0                                  NaN  ...
# 8.0                                  NaN  ...
#
#      2_22_comportamentos_incorretos_e_ou_inadequados_de_colegas_de_tr  \
# 0.0                                               23.0
# 1.0                                               20.0
# 2.0                                               21.0
# 3.0                                               20.0
# 4.0                                               11.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      2_23_falta_de_tempo_para_estar_com_a_familia_amigos  \
# 0.0                                                9.0
# 1.0                                               16.0
# 2.0                                               15.0
# 3.0                                               17.0
# 4.0                                               38.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      2_24_o_favoritismo_e_ou_discriminacao_encobertos_no_meu_local_de  \
# 0.0                                               23.0
# 1.0                                               18.0
# 2.0                                               20.0
# 3.0                                               13.0
# 4.0                                               21.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_passar_tempo_de_qualidade_com_f  \
# 0.0                                                4.0
# 1.0                                               43.0
# 2.0                                               23.0
# 3.0                                               18.0
# 4.0                                                7.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_tem_acesso_a_atividades_de_lazer_como_le  \
# 0.0                                                4.0
# 1.0                                               45.0
# 2.0                                               26.0
# 3.0                                               14.0
# 4.0                                                6.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_praticar_exercicios_fisicos  \
# 0.0                                               19.0
# 1.0                                               36.0
# 2.0                                               11.0
# 3.0                                               11.0
# 4.0                                               18.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_  \
# 0.0                                               18.0
# 1.0                                               47.0
# 2.0                                               16.0
# 3.0                                                8.0
# 4.0                                                6.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_dedicar_tempo_aos_estudos  \
# 0.0                                               24.0
# 1.0                                               31.0
# 2.0                                               21.0
# 3.0                                               11.0
# 4.0                                                8.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_realizar_as_atividades_domestic  \
# 0.0                                                2.0
# 1.0                                               33.0
# 2.0                                               38.0
# 3.0                                                8.0
# 4.0                                               14.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_descansar_o_suficiente_no_seu_c
# 0.0                                               11.0
# 1.0                                               51.0
# 2.0                                               16.0
# 3.0                                               12.0
# 4.0                                                5.0
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
# [9 rows x 44 columns]

# %%
porcentagens = df_final.apply(lambda col: col.value_counts(normalize=True) * 100)
porcentagens
# Out:
#      qual_a_sua_idade  como_voce_se_identifica  \
# 0.0               NaN                      NaN
# 1.0         37.894737                27.368421
# 2.0         24.210526                 9.473684
# 3.0         30.526316                62.105263
# 4.0          7.368421                 1.052632
# 5.0               NaN                      NaN
# 6.0               NaN                      NaN
# 7.0               NaN                      NaN
# 8.0               NaN                      NaN
#
#      qual_e_a_sua_identidade_de_genero  qual_e_a_sua_sexualidade  \
# 0.0                                NaN                       NaN
# 1.0                          25.263158                 69.473684
# 2.0                           1.052632                 10.526316
# 3.0                          70.526316                 16.842105
# 4.0                                NaN                  1.052632
# 5.0                                NaN                  1.052632
# 6.0                           3.157895                  1.052632
# 7.0                                NaN                       NaN
# 8.0                                NaN                       NaN
#
#      qual_o_seu_nivel_de_escolaridade  \
# 0.0                               NaN
# 1.0                          1.052632
# 2.0                          3.157895
# 3.0                          2.105263
# 4.0                         41.052632
# 5.0                               NaN
# 6.0                         17.894737
# 7.0                          7.368421
# 8.0                         27.368421
#
#      ha_quanto_tempo_voce_trabalha_em_shopping  em_qual_area_voce_trabalha  \
# 0.0                                        NaN                         NaN
# 1.0                                  28.421053                   85.263158
# 2.0                                  17.894737                         NaN
# 3.0                                  18.947368                    2.105263
# 4.0                                  16.842105                   10.526316
# 5.0                                   8.421053                    2.105263
# 6.0                                   9.473684                         NaN
# 7.0                                        NaN                         NaN
# 8.0                                        NaN                         NaN
#
#      quantas_horas_por_semana_voce_trabalha_no_total  voce_tem_outro_trabalho  \
# 0.0                                              NaN                      NaN
# 1.0                                         7.368421                 8.421053
# 2.0                                         4.210526                91.578947
# 3.0                                         2.105263                      NaN
# 4.0                                         5.263158                      NaN
# 5.0                                        30.526316                      NaN
# 6.0                                        50.526316                      NaN
# 7.0                                              NaN                      NaN
# 8.0                                              NaN                      NaN
#
#      voce_possui_dependentes_financeiros  ...  \
# 0.0                                  NaN  ...
# 1.0                            48.421053  ...
# 2.0                            51.578947  ...
# 3.0                                  NaN  ...
# 4.0                                  NaN  ...
# 5.0                                  NaN  ...
# 6.0                                  NaN  ...
# 7.0                                  NaN  ...
# 8.0                                  NaN  ...
#
#      2_22_comportamentos_incorretos_e_ou_inadequados_de_colegas_de_tr  \
# 0.0                                          24.210526
# 1.0                                          21.052632
# 2.0                                          22.105263
# 3.0                                          21.052632
# 4.0                                          11.578947
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      2_23_falta_de_tempo_para_estar_com_a_familia_amigos  \
# 0.0                                           9.473684
# 1.0                                          16.842105
# 2.0                                          15.789474
# 3.0                                          17.894737
# 4.0                                          40.000000
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      2_24_o_favoritismo_e_ou_discriminacao_encobertos_no_meu_local_de  \
# 0.0                                          24.210526
# 1.0                                          18.947368
# 2.0                                          21.052632
# 3.0                                          13.684211
# 4.0                                          22.105263
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_passar_tempo_de_qualidade_com_f  \
# 0.0                                           4.210526
# 1.0                                          45.263158
# 2.0                                          24.210526
# 3.0                                          18.947368
# 4.0                                           7.368421
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_tem_acesso_a_atividades_de_lazer_como_le  \
# 0.0                                           4.210526
# 1.0                                          47.368421
# 2.0                                          27.368421
# 3.0                                          14.736842
# 4.0                                           6.315789
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_praticar_exercicios_fisicos  \
# 0.0                                          20.000000
# 1.0                                          37.894737
# 2.0                                          11.578947
# 3.0                                          11.578947
# 4.0                                          18.947368
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_  \
# 0.0                                          18.947368
# 1.0                                          49.473684
# 2.0                                          16.842105
# 3.0                                           8.421053
# 4.0                                           6.315789
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_dedicar_tempo_aos_estudos  \
# 0.0                                          25.263158
# 1.0                                          32.631579
# 2.0                                          22.105263
# 3.0                                          11.578947
# 4.0                                           8.421053
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_realizar_as_atividades_domestic  \
# 0.0                                           2.105263
# 1.0                                          34.736842
# 2.0                                          40.000000
# 3.0                                           8.421053
# 4.0                                          14.736842
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
#      com_que_frequencia_voce_consegue_descansar_o_suficiente_no_seu_c
# 0.0                                          11.578947
# 1.0                                          53.684211
# 2.0                                          16.842105
# 3.0                                          12.631579
# 4.0                                           5.263158
# 5.0                                                NaN
# 6.0                                                NaN
# 7.0                                                NaN
# 8.0                                                NaN
#
# [9 rows x 44 columns]

# %%
df2_mode1 = df_final.mode(axis=0, numeric_only=True, dropna=True)
df2_mode2 = df2_mode1.head(1)
df2_mode = df2_mode2.T

df2_range = df_final.max()-df_final.min()

Q1 = df_final.quantile(0.25)
Q3 = df_final.quantile(0.75)
df2_IQR = Q3-Q1

df_summary = pd.DataFrame()
df_summary["Min"] = df_final.min()
df_summary["Max"] = df_final.max()
df_summary["Mode"] = df2_mode
df_summary["Median"] = df_final.median()
df_summary["Mean"] = df_final.mean()
df_summary["Range"] = df2_range
df_summary["IQR"] = df2_IQR
df_summary["Std Dev"] = df_final.std()
print(df_summary)
# Out:
#                                                     Min  Max  Mode  Median  \
# qual_a_sua_idade                                    1.0  4.0   1.0     2.0
# como_voce_se_identifica                             1.0  4.0   3.0     3.0
# qual_e_a_sua_identidade_de_genero                   1.0  6.0   3.0     3.0
# qual_e_a_sua_sexualidade                            1.0  6.0   1.0     1.0
# qual_o_seu_nivel_de_escolaridade                    1.0  8.0   4.0     6.0
# ha_quanto_tempo_voce_trabalha_em_shopping           1.0  6.0   1.0     3.0
# em_qual_area_voce_trabalha                          1.0  5.0   1.0     1.0
# quantas_horas_por_semana_voce_trabalha_no_total     1.0  6.0   6.0     6.0
# voce_tem_outro_trabalho                             1.0  2.0   2.0     2.0
# voce_possui_dependentes_financeiros                 1.0  2.0   2.0     2.0
# sua_residencia_e                                    1.0  2.0   1.0     1.0
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...  1.0  5.0   3.0     3.0
# 1_1_em_termos_gerais_a_minha_atividade_profissi...  0.0  4.0   2.0     2.0
# 2_1_a_falta_de_possibilidades_de_desenvolviment...  0.0  4.0   2.0     2.0
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...  0.0  4.0   3.0     3.0
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...  0.0  4.0   4.0     3.0
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho   0.0  4.0   1.0     1.0
# 2_5_trabalhar_muitas_horas_seguidas                 0.0  4.0   3.0     3.0
# 2_6_viver_com_os_recursos_financeiros_salario_d...  0.0  4.0   4.0     3.0
# 2_7_falta_de_condicoes_de_trabalho                  0.0  4.0   2.0     2.0
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...  0.0  4.0   2.0     2.0
# 2_9_falta_de_materiais_e_equipamentos_para_real...  0.0  4.0   0.0     1.0
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...  0.0  4.0   2.0     2.0
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...  0.0  4.0   3.0     3.0
# 2_12_conflitos_e_problemas_com_superiores_hiera...  0.0  4.0   1.0     1.0
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...  0.0  4.0   0.0     2.0
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...  0.0  4.0   4.0     3.0
# 2_15_falta_de_perspectivas_de_progressao_na_car...  0.0  4.0   2.0     2.0
# 2_16_a_sobrecarga_ou_excesso_de_trabalho            0.0  4.0   3.0     2.0
# 2_17_os_conflitos_interpessoais_com_outros_cole...  0.0  4.0   1.0     1.0
# 2_18_falta_de_meios_e_condicoes_de_trabalho         0.0  4.0   1.0     1.0
# 2_19_salario_inadequado_insuficiente                0.0  4.0   4.0     3.0
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...  0.0  4.0   1.0     2.0
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...  0.0  4.0   2.0     2.0
# 2_22_comportamentos_incorretos_e_ou_inadequados...  0.0  4.0   0.0     2.0
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...  0.0  4.0   4.0     3.0
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...  0.0  4.0   0.0     2.0
# com_que_frequencia_voce_consegue_passar_tempo_d...  0.0  4.0   1.0     2.0
# com_que_frequencia_voce_tem_acesso_a_atividades...  0.0  4.0   1.0     1.0
# com_que_frequencia_voce_consegue_praticar_exerc...  0.0  4.0   1.0     1.0
# com_que_frequencia_voce_consegue_ir_ao_medico_p...  0.0  4.0   1.0     1.0
# com_que_frequencia_voce_consegue_dedicar_tempo_...  0.0  4.0   1.0     1.0
# com_que_frequencia_voce_consegue_realizar_as_at...  0.0  4.0   2.0     2.0
# com_que_frequencia_voce_consegue_descansar_o_su...  0.0  4.0   1.0     1.0
#
#                                                         Mean  Range  IQR  \
# qual_a_sua_idade                                    2.073684    3.0  2.0
# como_voce_se_identifica                             2.368421    3.0  2.0
# qual_e_a_sua_identidade_de_genero                   2.578947    5.0  1.5
# qual_e_a_sua_sexualidade                            1.568421    5.0  1.0
# qual_o_seu_nivel_de_escolaridade                    5.557895    7.0  4.0
# ha_quanto_tempo_voce_trabalha_em_shopping           2.873684    5.0  3.0
# em_qual_area_voce_trabalha                          1.442105    4.0  0.0
# quantas_horas_por_semana_voce_trabalha_no_total     4.989474    5.0  1.0
# voce_tem_outro_trabalho                             1.915789    1.0  0.0
# voce_possui_dependentes_financeiros                 1.515789    1.0  1.0
# sua_residencia_e                                    1.473684    1.0  1.0
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...  3.021053    4.0  2.0
# 1_1_em_termos_gerais_a_minha_atividade_profissi...  2.463158    4.0  1.0
# 2_1_a_falta_de_possibilidades_de_desenvolviment...  2.315789    4.0  1.0
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...  2.442105    4.0  1.0
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...  2.589474    4.0  2.0
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho   1.442105    4.0  1.0
# 2_5_trabalhar_muitas_horas_seguidas                 2.568421    4.0  1.0
# 2_6_viver_com_os_recursos_financeiros_salario_d...  2.663158    4.0  2.0
# 2_7_falta_de_condicoes_de_trabalho                  1.705263    4.0  2.0
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...  2.200000    4.0  2.0
# 2_9_falta_de_materiais_e_equipamentos_para_real...  1.610526    4.0  3.0
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...  1.947368    4.0  2.0
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...  2.400000    4.0  2.0
# 2_12_conflitos_e_problemas_com_superiores_hiera...  1.663158    4.0  2.0
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...  1.600000    4.0  2.5
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...  2.589474    4.0  2.5
# 2_15_falta_de_perspectivas_de_progressao_na_car...  2.357895    4.0  1.0
# 2_16_a_sobrecarga_ou_excesso_de_trabalho            2.378947    4.0  1.5
# 2_17_os_conflitos_interpessoais_com_outros_cole...  1.336842    4.0  2.0
# 2_18_falta_de_meios_e_condicoes_de_trabalho         1.600000    4.0  1.0
# 2_19_salario_inadequado_insuficiente                2.652632    4.0  2.0
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...  1.957895    4.0  2.0
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...  2.157895    4.0  2.0
# 2_22_comportamentos_incorretos_e_ou_inadequados...  1.747368    4.0  2.0
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...  2.621053    4.0  3.0
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...  1.905263    4.0  2.0
# com_que_frequencia_voce_consegue_passar_tempo_d...  1.800000    4.0  2.0
# com_que_frequencia_voce_tem_acesso_a_atividades...  1.715789    4.0  1.0
# com_que_frequencia_voce_consegue_praticar_exerc...  1.715789    4.0  2.0
# com_que_frequencia_voce_consegue_ir_ao_medico_p...  1.336842    4.0  1.0
# com_que_frequencia_voce_consegue_dedicar_tempo_...  1.452632    4.0  1.5
# com_que_frequencia_voce_consegue_realizar_as_at...  1.989474    4.0  1.0
# com_que_frequencia_voce_consegue_descansar_o_su...  1.463158    4.0  1.0
#
#                                                      Std Dev
# qual_a_sua_idade                                    0.991905
# como_voce_se_identifica                             0.899795
# qual_e_a_sua_identidade_de_genero                   1.067697
# qual_e_a_sua_sexualidade                            0.996298
# qual_o_seu_nivel_de_escolaridade                    1.900256
# ha_quanto_tempo_voce_trabalha_em_shopping           1.638903
# em_qual_area_voce_trabalha                          1.088780
# quantas_horas_por_semana_voce_trabalha_no_total     1.491071
# voce_tem_outro_trabalho                             0.279177
# voce_possui_dependentes_financeiros                 0.502402
# sua_residencia_e                                    0.501956
# qual_a_distancia_de_sua_residencia_ao_seu_lugar...  1.436448
# 1_1_em_termos_gerais_a_minha_atividade_profissi...  0.931831
# 2_1_a_falta_de_possibilidades_de_desenvolviment...  1.113392
# 2_2_atitudes_negativas_relativamente_ao_nosso_t...  1.048969
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_...  1.267387
# 2_4_conflitos_e_problemas_com_colegas_de_trabalho   1.173427
# 2_5_trabalhar_muitas_horas_seguidas                 1.135994
# 2_6_viver_com_os_recursos_financeiros_salario_d...  1.190481
# 2_7_falta_de_condicoes_de_trabalho                  1.245192
# 2_8_incompreensao_face_ao_nosso_trabalho_por_pa...  1.268271
# 2_9_falta_de_materiais_e_equipamentos_para_real...  1.370624
# 2_10_o_excesso_de_trabalho_e_ou_tarefas_de_cara...  1.291284
# 2_11_ter_de_realizar_muitas_horas_seguidas_de_t...  1.283280
# 2_12_conflitos_e_problemas_com_superiores_hiera...  1.365304
# 2_13_cumprir_com_aquilo_que_e_esperado_pelas_pe...  1.307914
# 2_14_falta_de_tempo_para_dar_apoio_e_conviver_c...  1.324842
# 2_15_falta_de_perspectivas_de_progressao_na_car...  1.270917
# 2_16_a_sobrecarga_ou_excesso_de_trabalho            1.264734
# 2_17_os_conflitos_interpessoais_com_outros_cole...  1.216994
# 2_18_falta_de_meios_e_condicoes_de_trabalho         1.299754
# 2_19_salario_inadequado_insuficiente                1.235713
# 2_20_a_falta_de_apoio_e_ajuda_por_parte_dos_meu...  1.421086
# 2_21_nivel_de_exigencia_das_pessoas_a_quem_pres...  1.315341
# 2_22_comportamentos_incorretos_e_ou_inadequados...  1.344559
# 2_23_falta_de_tempo_para_estar_com_a_familia_am...  1.400448
# 2_24_o_favoritismo_e_ou_discriminacao_encoberto...  1.480897
# com_que_frequencia_voce_consegue_passar_tempo_d...  1.037591
# com_que_frequencia_voce_tem_acesso_a_atividades...  0.985676
# com_que_frequencia_voce_consegue_praticar_exerc...  1.411677
# com_que_frequencia_voce_consegue_ir_ao_medico_p...  1.077927
# com_que_frequencia_voce_consegue_dedicar_tempo_...  1.227074
# com_que_frequencia_voce_consegue_realizar_as_at...  1.056839
# com_que_frequencia_voce_consegue_descansar_o_su...  1.029465

# %% [markdown]
# # 4. **Análise inferencial**

# %% [markdown]
# ## 2 groups with different population:

# %% [markdown]
# ### Nivel de estresse:

# %%
from scipy.stats import mannwhitneyu

# %%
from scipy.stats import shapiro

# %% [markdown]
# #### Qual é a sua identidade de genero (Homem cis e mulher cis)

# %%
df1 = df_final[df_final['qual_e_a_sua_identidade_de_genero'] == 1] # Homem cis
df2 = df_final[df_final['qual_e_a_sua_identidade_de_genero'] == 3] # Mulher cis

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.9038716984041921), pvalue=np.float64(3.149024077061513e-25))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.9193240825524727), pvalue=np.float64(4.318451695459641e-37))

# %%
mannwhitneyu(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# MannwhitneyuResult(statistic=np.float64(861.5), pvalue=np.float64(0.5880711460983482))

# %% [markdown]
# #### Tipo de residencia (propria ou alugada)

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['sua_residencia_e'])
mean_ranks = df_final.groupby('sua_residencia_e')['Rank'].mean()
print(mean_ranks)
# Out:
# sua_residencia_e
# 1    25.5
# 2    73.0
# Name: Rank, dtype: float64
# <ipython-input-480-277e42df84ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['sua_residencia_e'])

# %%
df1 = df_final[df_final['sua_residencia_e'] == 1] # Alugada
df2 = df_final[df_final['sua_residencia_e'] == 2] # Propria

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.44656779746018016), pvalue=np.float64(5.7286207633962136e-64))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.2288918169717854), pvalue=np.float64(5.73846523451111e-68))

# %%
mannwhitneyu(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# MannwhitneyuResult(statistic=np.float64(1220.0), pvalue=np.float64(0.4576552108295969))

# %% [markdown]
# #### Tem outro trabalho (sim ou nao)

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['voce_tem_outro_trabalho'])
mean_ranks = df_final.groupby('voce_tem_outro_trabalho')['Rank'].mean()
print(mean_ranks)
# Out:
# voce_tem_outro_trabalho
# 1     4.5
# 2    52.0
# Name: Rank, dtype: float64
# <ipython-input-485-b44d9fd7907f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['voce_tem_outro_trabalho'])

# %%
df1 = df_final[df_final['voce_tem_outro_trabalho'] == 1] # Sim
df2 = df_final[df_final['voce_tem_outro_trabalho'] == 2] # Nao

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.9026099437064368), pvalue=np.float64(1.9508537217626947e-14))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.2729313624852068), pvalue=np.float64(2.6984274155335093e-82))

# %%
mannwhitneyu(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# MannwhitneyuResult(statistic=np.float64(379.0), pvalue=np.float64(0.6664693347717854))

# %% [markdown]
# #### Possui dependentes financeiros? (Sim ou nao)

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['voce_possui_dependentes_financeiros'])
mean_ranks = df_final.groupby('voce_possui_dependentes_financeiros')['Rank'].mean()
print(mean_ranks)
# Out:
# voce_possui_dependentes_financeiros
# 1    23.5
# 2    71.0
# Name: Rank, dtype: float64
# <ipython-input-490-74adcc7356cb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['voce_possui_dependentes_financeiros'])

# %%
df1 = df_final[df_final['voce_possui_dependentes_financeiros'] == 1] # Sim
df2 = df_final[df_final['voce_possui_dependentes_financeiros'] == 2] # Nao

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.48302019327057255), pvalue=np.float64(6.070476622736685e-61))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.22992272369675903), pvalue=np.float64(7.373057059592469e-70))

# %%
mannwhitneyu(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# MannwhitneyuResult(statistic=np.float64(1243.0), pvalue=np.float64(0.3644305907855542))

# %% [markdown]
# ### Quantidade de vezes que consegue ir ao medico ou cuidar da saude:

# %% [markdown]
# #### Genero (Homem cis e mulher cis)

# %%
from scipy.stats import ttest_ind

# %%
df1 = df_final[df_final['qual_e_a_sua_identidade_de_genero'] == 1] # HOmem cis
df2 = df_final[df_final['qual_e_a_sua_identidade_de_genero'] == 3] # Mulher cis

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.22944703950005219), pvalue=np.float64(9.065938427384945e-55))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.2498577884226243), pvalue=np.float64(1.3003080415707683e-76))

# %%
mannwhitneyu(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# MannwhitneyuResult(statistic=np.float64(731.0), pvalue=np.float64(0.481131141983025))

# %% [markdown]
# #### Tipo de residencia (alugada ou propria)

# %%
df1 = df_final[df_final['sua_residencia_e'] == 1] # Alugada
df2 = df_final[df_final['sua_residencia_e'] == 2] # Propria

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.2367851214363792), pvalue=np.float64(3.8417953130987524e-70))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.25189156696937487), pvalue=np.float64(2.1934508625444102e-67))

# %%
mannwhitneyu(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# MannwhitneyuResult(statistic=np.float64(1033.5), pvalue=np.float64(0.46623271651935294))

# %% [markdown]
# #### Tem outro trabalho (sim ou nao)

# %%
df1 = df_final[df_final['voce_tem_outro_trabalho'] == 1] # Sim
df2 = df_final[df_final['voce_tem_outro_trabalho'] == 2] # Nao

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.2438835458821773), pvalue=np.float64(1.0575523080498262e-35))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.2431193585996564), pvalue=np.float64(3.588287592356067e-83))

# %%
mannwhitneyu(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# MannwhitneyuResult(statistic=np.float64(317.0), pvalue=np.float64(0.6606007085962738))

# %% [markdown]
# #### Possui dependentes financeiros (sim ou nao)

# %%
df1 = df_final[df_final['voce_possui_dependentes_financeiros'] == 1] # Sim
df2 = df_final[df_final['voce_possui_dependentes_financeiros'] == 2] # Nao

# %%
shapiro(df1)
# Out:
# ShapiroResult(statistic=np.float64(0.48302019327057255), pvalue=np.float64(6.070476622736685e-61))

# %%
shapiro(df2)
# Out:
# ShapiroResult(statistic=np.float64(0.22992272369675903), pvalue=np.float64(7.373057059592469e-70))

# %%
mannwhitneyu(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# MannwhitneyuResult(statistic=np.float64(1179.5), pvalue=np.float64(0.6774202368070268))

# %% [markdown]
# ## 3 or more groups with different population:

# %%
from scipy.stats import kruskal

# %% [markdown]
# ### Nivel de estresse:

# %% [markdown]
# #### Qual é a sua idade

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['qual_a_sua_idade'])
mean_ranks = df_final.groupby('qual_a_sua_idade')['Rank'].mean()
print(mean_ranks)
# Out:
# qual_a_sua_idade
# 1    18.5
# 2    48.0
# 3    74.0
# 4    92.0
# Name: Rank, dtype: float64
# <ipython-input-513-e2dd7e477fdd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['qual_a_sua_idade'])

# %%
df1 = df_final[df_final['qual_a_sua_idade'] == 1]
df2 = df_final[df_final['qual_a_sua_idade'] == 2]
df3 = df_final[df_final['qual_a_sua_idade'] == 3]
df4 = df_final[df_final['qual_a_sua_idade'] == 4]

# %%
kruskal(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(0.6179241083191611), pvalue=np.float64(0.8923170774006877))

# %% [markdown]
# #### Escolaridade

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['qual_o_seu_nivel_de_escolaridade'])
mean_ranks = df_final.groupby('qual_o_seu_nivel_de_escolaridade')['Rank'].mean()
print(mean_ranks)
# Out:
# qual_o_seu_nivel_de_escolaridade
# 1.0     1.0
# 2.0     3.0
# 3.0     5.5
# 4.0    26.0
# 6.0    54.0
# 7.0    66.0
# 8.0    82.5
# Name: Rank, dtype: float64
# <ipython-input-516-cc402fcf69e1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['qual_o_seu_nivel_de_escolaridade'])

# %%
df4 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 4]
df8 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 8]
df6 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 6]
df7 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 7]

# %%
kruskal(df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df8["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df6["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df7["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(0.6032363200662548), pvalue=np.float64(0.8956910937636453))

# %% [markdown]
# #### tempo de trabalho

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['ha_quanto_tempo_voce_trabalha_em_shopping'])
mean_ranks = df_final.groupby('ha_quanto_tempo_voce_trabalha_em_shopping')['Rank'].mean()
print(mean_ranks)
# Out:
# ha_quanto_tempo_voce_trabalha_em_shopping
# 1    14.0
# 2    36.0
# 3    53.5
# 4    70.5
# 5    82.5
# 6    91.0
# Name: Rank, dtype: float64
# <ipython-input-519-2f7c2d6ad261>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['ha_quanto_tempo_voce_trabalha_em_shopping'])

# %%
df1 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 1]
df2 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 2]
df3 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 3]
df4 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 4]
df5 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 5]
df6 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 6]

# %%
kruskal(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df5["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df6["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(4.534666542734254), pvalue=np.float64(0.475258615285147))

# %% [markdown]
# #### trabalho por semana

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['quantas_horas_por_semana_voce_trabalha_no_total'])
mean_ranks = df_final.groupby('quantas_horas_por_semana_voce_trabalha_no_total')['Rank'].mean()
print(mean_ranks)
# Out:
# quantas_horas_por_semana_voce_trabalha_no_total
# 1     4.0
# 2     9.5
# 3    12.5
# 4    16.0
# 5    33.0
# 6    71.5
# Name: Rank, dtype: float64
# <ipython-input-522-083962673e4f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['quantas_horas_por_semana_voce_trabalha_no_total'])

# %%
df1 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 1]
df2 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 2]
df3 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 3]
df4 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 4]
df5 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 5]
df6 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 6]

# %%
kruskal(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df5["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df6["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(7.837583356764945), pvalue=np.float64(0.16541680914520812))

# %% [markdown]
# #### Distancia do trabalho

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'])
mean_ranks = df_final.groupby('qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho')['Rank'].mean()
print(mean_ranks)
# Out:
# qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho
# 1    10.5
# 2    28.5
# 3    47.0
# 4    66.5
# 5    85.5
# Name: Rank, dtype: float64
# <ipython-input-525-4d9c994cbcbb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'])

# %%
df1 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 1]
df2 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 2]
df3 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 3]
df4 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 4]
df5 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 5]

# %%
kruskal(df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df5["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(3.6805422925301894), pvalue=np.float64(0.4509622595842526))

# %% [markdown]
# #### Fatal de posibilidade de desenvolvimento e promocao

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'])
mean_ranks = df_final.groupby('2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c')['Rank'].mean()
print(mean_ranks)
# Out:
# 2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c
# 0.0     3.5
# 1.0    13.5
# 2.0    38.0
# 3.0    67.5
# 4.0    87.5
# Name: Rank, dtype: float64
# <ipython-input-528-f3f77bc77563>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'])

# %%
df1 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 1]
df2 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 2]
df3 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 3]
df4 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 4]
df0 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 0]

# %%
kruskal(df0["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(18.43082618612209), pvalue=np.float64(0.0010163724363766733))

# %%
from pandas import crosstab
import matplotlib.pyplot as plt

# %% [markdown]
# #### Atitudes negativas dos clientes

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'])
mean_ranks = df_final.groupby('2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte')['Rank'].mean()
print(mean_ranks)
# Out:
# 2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte
# 0     2.5
# 1    11.0
# 2    32.5
# 3    64.0
# 4    88.0
# Name: Rank, dtype: float64
# <ipython-input-532-3f57385e0df6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'])

# %%
df1 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 1]
df2 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 2]
df3 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 3]
df4 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 4]
df0 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 0]

# %%
kruskal(df0["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(35.39901821548482), pvalue=np.float64(3.8461929534388653e-07))

# %% [markdown]
# #### Falta de tempo para uma boa relacao com os parentes

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'])
mean_ranks = df_final.groupby('2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma')['Rank'].mean()
print(mean_ranks)
# Out:
# 2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma
# 0     3.5
# 1    14.5
# 2    32.0
# 3    53.5
# 4    80.5
# Name: Rank, dtype: float64
# <ipython-input-535-8b3fb85e3055>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'])

# %%
df1 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 1]
df2 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 2]
df3 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 3]
df4 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 4]
df0 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 0]

# %%
kruskal(df0["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(30.70960200708963), pvalue=np.float64(3.50864894708928e-06))

# %% [markdown]
# #### Trabalhar muitas horas seguidas

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['2_5_trabalhar_muitas_horas_seguidas'])
mean_ranks = df_final.groupby('2_5_trabalhar_muitas_horas_seguidas')['Rank'].mean()
print(mean_ranks)
# Out:
# 2_5_trabalhar_muitas_horas_seguidas
# 0     2.5
# 1    12.0
# 2    30.0
# 3    57.0
# 4    84.5
# Name: Rank, dtype: float64
# <ipython-input-538-cd4d9db52ab9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['2_5_trabalhar_muitas_horas_seguidas'])

# %%
df1 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 1]
df2 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 2]
df3 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 3]
df4 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 4]
df0 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 0]

# %%
kruskal(df0["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(32.05749165688471), pvalue=np.float64(1.862030532942196e-06))

# %% [markdown]
# #### Viver com os recursos e salarios

# %%
from scipy.stats import rankdata

df_final['Rank'] = rankdata(df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'])
mean_ranks = df_final.groupby('2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho')['Rank'].mean()
print(mean_ranks)
# Out:
# 2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho
# 0     2.5
# 1    12.0
# 2    29.0
# 3    52.5
# 4    81.0
# Name: Rank, dtype: float64
# <ipython-input-541-2b56a1469c3f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Rank'] = rankdata(df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'])

# %%
df1 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 1]
df2 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 2]
df3 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 3]
df4 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 4]
df0 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 0]

# %%
kruskal(df0["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(16.362155817912605), pvalue=np.float64(0.0025697843555528084))

# %% [markdown]
# #### Falta de condicoes de trabalho

# %%
df1 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 1]
df2 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 2]
df3 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 3]
df4 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 4]
df0 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 0]

# %%
kruskal(df0["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df3["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df4["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"])
# Out:
# KruskalResult(statistic=np.float64(25.807908094824327), pvalue=np.float64(3.4595713049335895e-05))

# %% [markdown]
# ### Quantidade de vezes que consegue ir ao medico ou se cuidar

# %% [markdown]
# #### Idade

# %%
df1 = df_final[df_final['qual_a_sua_idade'] == 1] #
df2 = df_final[df_final['qual_a_sua_idade'] == 2] #
df3 = df_final[df_final['qual_a_sua_idade'] == 3] #
df4 = df_final[df_final['qual_a_sua_idade'] == 4] #

# %%
kruskal(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(0.564682942844437), pvalue=np.float64(0.9044676199229749))

# %% [markdown]
# #### Escolaridade

# %%
df4 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 4] #
df8 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 8] #
df6 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 6] #
df7 = df_final[df_final['qual_o_seu_nivel_de_escolaridade'] == 7] #

# %%
kruskal(df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df8["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df6["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df7["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(0.07173746923441382), pvalue=np.float64(0.9949983821620277))

# %% [markdown]
# #### tempo de trabalho

# %%
df1 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 1]
df2 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 2]
df3 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 3]
df4 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 4]
df5 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 5]
df6 = df_final[df_final['ha_quanto_tempo_voce_trabalha_em_shopping'] == 6]

# %%
kruskal(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df5["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df6["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(4.822062891252762), pvalue=np.float64(0.4379797421541183))

# %% [markdown]
# #### trabalho por semana

# %%
df1 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 1]
df2 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 2]
df3 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 3]
df4 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 4]
df5 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 5]
df6 = df_final[df_final['quantas_horas_por_semana_voce_trabalha_no_total'] == 6]

# %%
kruskal(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df5["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df6["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(2.7125399402184622), pvalue=np.float64(0.7441998512381965))

# %% [markdown]
# #### Distancia do trabalho

# %%
df1 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 1]
df2 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 2]
df3 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 3]
df4 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 4]
df5 = df_final[df_final['qual_a_distancia_de_sua_residencia_ao_seu_lugar_de_trabalho'] == 5]

# %%
kruskal(df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df5["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(1.5684070067232092), pvalue=np.float64(0.8144588253140925))

# %% [markdown]
# #### Fatal de posibilidade de desenvolvimento e promocao

# %%
df1 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 1]
df2 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 2]
df3 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 3]
df4 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 4]
df0 = df_final[df_final['2_1_a_falta_de_possibilidades_de_desenvolvimento_e_promocao_na_c'] == 0]

# %%
kruskal(df0["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df1["1_1_em_termos_gerais_a_minha_atividade_profissional_provoca_me"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(7.465049181352326), pvalue=np.float64(0.1132603882373981))

# %% [markdown]
# #### Atitudes negativas dos clientes

# %%
df1 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 1]
df2 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 2]
df3 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 3]
df4 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 4]
df0 = df_final[df_final['2_2_atitudes_negativas_relativamente_ao_nosso_trabalho_por_parte'] == 0]

# %%
kruskal(df0["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(7.48902470400094), pvalue=np.float64(0.11219423191900753))

# %% [markdown]
# #### Falta de tempo para uma boa relacao com os parentes

# %%
df1 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 1]
df2 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 2]
df3 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 3]
df4 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 4]
df0 = df_final[df_final['2_3_falta_de_tempo_para_manter_uma_boa_relacao_com_as_pessoas_ma'] == 0]

# %%
kruskal(df0["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(12.571218049292721), pvalue=np.float64(0.01357252176359441))

# %% [markdown]
# #### Trabalhar muitas horas seguidas

# %%
df1 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 1]
df2 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 2]
df3 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 3]
df4 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 4]
df0 = df_final[df_final['2_5_trabalhar_muitas_horas_seguidas'] == 0]

# %%
kruskal(df0["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(9.891329965747223), pvalue=np.float64(0.042298544472213435))

# %% [markdown]
# #### Viver com os recursos e salarios

# %%
df1 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 1]
df2 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 2]
df3 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 3]
df4 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 4]
df0 = df_final[df_final['2_6_viver_com_os_recursos_financeiros_salario_de_que_disponho'] == 0]

# %%
kruskal(df0["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(8.218630819405933), pvalue=np.float64(0.08388990578804138))

# %% [markdown]
# #### Falta de condicoes de trabalho

# %%
df1 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 1]
df2 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 2]
df3 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 3]
df4 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 4]
df0 = df_final[df_final['2_7_falta_de_condicoes_de_trabalho'] == 0]

# %%
kruskal(df0["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df1["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df2["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df3["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"], df4["com_que_frequencia_voce_consegue_ir_ao_medico_para_check_ups_ou_"])
# Out:
# KruskalResult(statistic=np.float64(7.858589721845253), pvalue=np.float64(0.09689775647592837))
